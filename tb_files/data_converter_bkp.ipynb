# %%
import numpy as np

full_in_data = []

with open("data/tb_track_data.dat", "r") as file:
  for i in range(100):
    line = file.readline()
    line = line.strip()
    data = line.split(" ")
    # print(data)
    data = [float(d) for d in data]
    # data = np.array(data)
    full_in_data.append(data)

full_in_data = np.array(full_in_data)
print("full in data:")
print(full_in_data)
  



out_data = []

with open("data/tb_NNscore.dat", "r") as file:
  for i in range(100):
    line = file.readline()
    line = line.strip()
    data = line.split(" ")
    # print(data)
    data = [float(d) for d in data]
    data = data[0]
    # data = np.array(data)
    out_data.append(data)

out_data = np.array(out_data)
print("\nout data:")
print(out_data)
# Out:
# full in data:
# [[276.00345  379.07703  546.0151   ...  97.06505  110.08161  187.81969 ]
#  [275.02087  377.18805  526.99664  ...  91.779724 102.646774 158.4044  ]
#  [263.57776  362.60608  511.30563  ... 197.34447  238.48196  307.91565 ]
#  ...
#  [377.02267  545.37244  731.92456  ... 262.02972  332.68005    0.      ]
#  [264.24435  374.44348  524.6667   ... 165.10039  226.34856  325.25714 ]
#  [273.11325  374.248    520.5675   ... 100.95584  153.72768  134.77716 ]]
#
# out data:
# [1.42872950e-06 7.24770100e-01 9.78337760e-01 4.89071000e-03
#  9.88550540e-01 1.63644550e-04 1.29625200e-03 3.53143330e-05
#  2.63793300e-01 1.08516580e-13 2.04688300e-03 1.09361660e-09
#  1.28491940e-06 1.76444150e-07 1.66928950e-05 9.99956000e-01
#  1.41441820e-04 5.76652300e-02 1.32198150e-06 7.82165650e-11
#  1.18941370e-02 4.48393700e-19 1.41253220e-05 9.96875500e-01
#  8.30873940e-07 7.09086660e-04 1.17826460e-03 3.90982630e-03
#  6.94756450e-01 9.46399870e-01 3.25575570e-10 1.89310310e-03
#  2.83655930e-10 4.26408700e-05 7.60278100e-07 8.41726800e-01
#  2.57542730e-03 1.01014970e-03 4.83899330e-21 5.91848180e-15
#  9.89044550e-01 3.41037330e-01 4.41372400e-04 2.21840080e-09
#  9.68290800e-01 1.96101880e-05 1.92606450e-03 8.86913300e-19
#  1.96297020e-07 5.68233950e-09 2.78851560e-14 3.47328600e-01
#  5.71953650e-02 9.99846340e-01 6.34852270e-20 1.00362300e-03
#  4.72860040e-02 6.14599300e-01 5.19047600e-12 5.28986060e-05
#  5.76139920e-08 1.61319970e-04 9.95989600e-01 1.18833020e-04
#  5.41136160e-20 7.88904900e-01 9.95493050e-01 6.78867100e-04
#  1.90892280e-05 4.06950700e-04 5.93283800e-05 3.98397450e-04
#  5.72707360e-08 9.78922300e-01 1.13823344e-17 1.14734390e-18
#  1.76136820e-07 1.16524330e-10 4.51743600e-04 1.40044090e-03
#  2.43641350e-07 9.80725650e-01 9.56014500e-01 1.01749720e-14
#  7.79108760e-01 6.82372900e-08 4.08080280e-19 8.35597500e-04
#  4.05399380e-01 8.33481550e-04 8.75848850e-05 9.30035100e-03
#  3.79085540e-04 7.90454860e-07 1.09573010e-02 7.88367230e-07
#  3.06625200e-09 9.87893600e-01 1.23969720e-14 1.10083840e-04]

# %%
full_in_data.shape
# Out:
# (100, 15)

# %%
import matplotlib.pyplot as plt

in_data = []
NHITS = 5

for d in range(len(full_in_data)):
  # data = [full_in_data[d][i:i+3] for i in range(0, len(full_in_data[d]), 3)]
  data = []
  for i in range(NHITS):
    x = full_in_data[d][i + 0 * NHITS]
    y = full_in_data[d][i + 1 * NHITS]
    z = full_in_data[d][i + 2 * NHITS]
    data.append(np.array([x,y,z]))
  data = np.array(data)
  in_data.append(data)
in_data = np.array(in_data)
print(in_data.shape)
print(in_data)

# plt.scatter(in_data[0, ])
# Out:
# (100, 5, 3)
# [[[276.00345   81.697754  58.2015  ]
#   [379.07703  109.385     24.167248]
#   [546.0151   148.64362   97.06505 ]
#   [733.9022   187.30806  110.08161 ]
#   [976.06854  225.11757  187.81969 ]]
#
#  [[275.02087   92.31906   39.542164]
#   [377.18805  126.52965   59.975372]
#   [526.99664  173.1099    91.779724]
#   [730.56714  234.15543  102.646774]
#   [954.1053   297.29663  158.4044  ]]
#
#  [[263.57776  119.52835  148.4035  ]
#   [362.60608  171.8978   164.05258 ]
#   [511.30563  257.77475  197.34447 ]
#   [669.59247  359.818    238.48196 ]
#   [862.47705  500.4663   307.91565 ]]
#
#  ...
#
#  [[377.02267  128.03017  158.44362 ]
#   [545.37244  173.18336  208.18793 ]
#   [731.92456  215.0885   262.02972 ]
#   [975.219    257.5602   332.68005 ]
#   [  0.         0.         0.      ]]
#
#  [[264.24435  116.31339  170.56284 ]
#   [374.44348  151.43953  124.70367 ]
#   [524.6667   185.6815   165.10039 ]
#   [732.15454  211.85268  226.34856 ]
#   [976.4946   208.8615   325.25714 ]]
#
#  [[273.11325  112.93935   88.9025  ]
#   [374.248    153.21921   64.69827 ]
#   [520.5675   207.8046   100.95584 ]
#   [707.40643  273.20377  153.72768 ]
#   [930.5677   349.80942  134.77716 ]]]

# %%
index = 0

# %%
plt.plot(in_data[index,:,0], in_data[index,:,1], marker='o', zorder=2)
plt.grid(True)
plt.title("Index {} -> NN score: {}".format(index, out_data[index]))
print(in_data[index])
plt.xlim(0, 1000)
plt.ylim(0, 1000)
plt.show()
index += 1
# Out:
# [[276.00345   81.697754  58.2015  ]
#  [379.07703  109.385     24.167248]
#  [546.0151   148.64362   97.06505 ]
#  [733.9022   187.30806  110.08161 ]
#  [976.06854  225.11757  187.81969 ]]

# %%
plt.scatter(in_data[:,:,0], in_data[:,:,1], s=15, edgecolor='black', color='red', zorder=2)
plt.grid(True)
plt.show()

# %%
plt.scatter(in_data[:,:,0], in_data[:,:,1], s=15, edgecolor='black', color='red', alpha=0.1, zorder=2)
plt.scatter(in_data[:,0,0], in_data[:,0,1], s=15, edgecolor='black', color='green', zorder=3)
plt.scatter(in_data[:,1,0], in_data[:,1,1], s=15, edgecolor='black', color='yellow', zorder=3)
plt.scatter(in_data[:,2,0], in_data[:,2,1], s=15, edgecolor='black', color='pink', zorder=3)
plt.scatter(in_data[:,3,0], in_data[:,3,1], s=15, edgecolor='black', color='purple', zorder=3)
plt.scatter(in_data[:,4,0], in_data[:,4,1], s=15, edgecolor='black', color='blue', zorder=3)
plt.grid(True)
plt.xlim(0, 1100)
plt.ylim(0, 700)
plt.show()

# %%
print(np.where((in_data[:,3,1] < 100) & (in_data[:,3,0] > 800)))

print(in_data[15])
print(out_data[15])
print()
print(in_data[62])
print(out_data[62])
# Out:
# (array([15, 62]),)
# [[400.7317    81.49164  101.59152 ]
#  [556.9027    89.382675 144.4417  ]
#  [758.0071    81.43328  201.05457 ]
#  [999.0209    43.436317 265.336   ]
#  [  0.         0.         0.      ]]
# 0.999956
#
# [[400.88727   82.840225 121.86447 ]
#  [556.917     89.740814 175.55042 ]
#  [757.77954   79.14518  240.84225 ]
#  [997.9218    36.083214 306.69562 ]
#  [  0.         0.         0.      ]]
# 0.9959896

# %%
trim_track = in_data[:100]
trim_NN = out_data[:100]

print(trim_track.shape)
print(trim_NN.shape)

THRESHOLD = 0.5
trim2_track = trim_track[trim_NN > THRESHOLD]
trim2_NN = trim_NN[trim_NN > THRESHOLD]
trim2_ids = np.arange(len(trim_track))[trim_NN > THRESHOLD]

print(trim2_track.shape)
print(trim2_NN.shape)
print(trim2_ids)
# Out:
# (100, 5, 3)
# (100,)
# (20, 5, 3)
# (20,)
# [ 1  2  4 15 23 28 29 35 40 44 53 57 62 65 66 73 81 82 84 97]

# %%
plt.scatter(trim_track[:,:,0], trim_track[:,:,1], s=15, edgecolor='black', color='red', alpha=0.1, zorder=2)
plt.scatter(trim2_track[:,:,0], trim2_track[:,:,1], s=15, edgecolor='black', color='green', alpha=0.5, zorder=2)
plt.grid(True)
plt.show()

# %%
with open("tb_output.dat", 'r') as file:
  data = file.read().split("\n")[:-1]

trks = [data[d:d+5+1] for d in range(0,len(data), 5+1)]
print(trks)

nn_score = [d[0] for d in trks]
trks = [d[1:] for d in trks]

print(nn_score)
print(trks)

tracks = []
for trk in trks:
  track = []
  for hit in trk:
    hits = hit.split(" ")
    # hits = [int(h) for h in hits]
    hits = [float(h) for h in hits]
    track.append(hits)
  track = np.array(track)
  tracks.append(track)
tracks = np.array(tracks)

print(tracks.shape)
print(tracks)
# Out:
# [['0.978333', '263.563 119.5 148.375', '362.594 171.875 164.031', '511.281 257.75 197.344', '669.563 359.813 238.469', '862.469 500.438 307.906'], ['0.999939', '400.719 81.4688 101.563', '556.875 89.375 144.438', '758 81.4063 201.031', '999 43.4063 265.313', '0 0 0'], ['0.996826', '247.906 150.125 117.531', '335.625 218.656 117.281', '449.938 323.313 135.281', '586.188 476.25 155.906', '729.344 688.5 183.219'], ['0.841675', '276.406 77.1563 -17.1563', '380.063 100.219 6.59375', '546.438 131.406 33.3438', '752.563 160.094 77.6563', '981.531 179.406 101.625'], ['0.989014', '265.781 108.781 -14.6563', '375.594 140.969 30.5938', '545.25 177.406 84.6875', '733.031 199.375 144.844', '976.719 200.125 221.969'], ['0.968262', '263.219 121.219 57.375', '373 164.531 79.0625', '519.125 215
#   [999.       43.4063  265.313  ]
#   [  0.        0.        0.     ]]
#
#  [[247.906   150.125   117.531  ]
#   [335.625   218.656   117.281  ]
#   [449.938   323.313   135.281  ]
#   [586.188   476.25    155.906  ]
#   [729.344   688.5     183.219  ]]
#
#  [[276.406    77.1563  -17.1563 ]
#   [380.063   100.219     6.59375]
#   [546.438   131.406    33.3438 ]
#   [752.563   160.094    77.6563 ]
#   [981.531   179.406   101.625  ]]
#
#  [[265.781   108.781   -14.6563 ]
#   [375.594   140.969    30.5938 ]
#   [545.25    177.406    84.6875 ]
#   [733.031   199.375   144.844  ]
#   [976.719   200.125   221.969  ]]
#
#  [[263.219   121.219    57.375  ]
#   [373.      164.531    79.0625 ]
#   [519.125   215.469   101.188  ]
#   [707.625   271.844   130.656  ]
#   [950.531   328.625   168.875  ]]
#
#  [[352.375   170.375    22.9375 ]
#   [494.563   250.156    37.375  ]
#   [669.719   359.313    56.625  ]
#   [860.75    493.188    77.25   ]
#   [  0.        0.        0.     ]]
#
#  [[273.844   104.719   -64.0938 ]
#   [375.906   138.094   -38.875  ]
#   [525.281   182.281    -7.1875 ]
#   [730.625   233.156    36.5625 ]
#   [956.375   277.188    84.4688 ]]
#
#  [[260.094   136.313   108.281  ]
#   [349.094   179.813   134.188  ]
#   [511.625   255.938   178.5    ]
#   [687.063   333.75    223.813  ]
#   [906.781   424.688   281.438  ]]
#
#  [[275.281    89.2813   78.5938 ]
#   [377.406   124.25    102.219  ]
#   [526.25    177.031   147.344  ]
#   [729.188   253.188   195.031  ]
#   [949.219   340.063   266.875  ]]
#
#  [[261.375   130.      -51.25   ]
#   [351.313   173.406   -43.7813 ]
#   [512.844   249.375   -20.5625 ]
#   [684.031   327.594    -3.5    ]
#   [902.563   424.094    19.8438 ]]
#
#  [[377.      128.      158.438  ]
#   [545.344   173.156   208.188  ]
#   [731.906   215.063   262.     ]
#   [975.219   257.531   332.656  ]
#   [  0.        0.        0.     ]]]

# %%
plt.scatter(trim_track[:,:,0], trim_track[:,:,1], s=15, edgecolor='black', color='pink', alpha=0.1, zorder=2, label="All Data")
# plt.scatter(trim2_track[:,:,0], trim2_track[:,:,1], s=15, edgecolor='black', color='green', alpha=0.3, zorder=3, label="NNScore>0.7")
# plt.scatter(tracks[:,:,0], tracks[:,:,1], s=15, edgecolor='black', color='red', alpha=1, zorder=4)
first = "FPGA returned"
for t in tracks:
  t = np.array([h for h in t if h[0] != 0])
  plt.plot(t[:,0], t[:,1], marker='o', ms=np.sqrt(15), markeredgecolor='black', linestyle=':', color='red', alpha=1, zorder=5, label=first)
  first = None

first = "NNScore>0.5"
for t in trim2_track:
  t = np.array([h for h in t if h[0] != 0])
  plt.plot(t[:,0], t[:,1], marker='o', ms=np.sqrt(15), markeredgecolor='black', linestyle=':', color='green', alpha=0.7, zorder=4, label=first)
  first = None
print(trim2_NN)
plt.grid(True)
plt.legend()
plt.savefig("rejected_tracks.png", dpi=200)
plt.show()
# Out:
# [0.7247701  0.97833776 0.98855054 0.999956   0.9968755  0.69475645
#  0.94639987 0.8417268  0.98904455 0.9682908  0.99984634 0.6145993
#  0.9959896  0.7889049  0.99549305 0.9789223  0.98072565 0.9560145
#  0.77910876 0.9878936 ]

# %%
labels = ["X","Y","Z"]
from matplotlib.colors import LinearSegmentedColormap
bounds = [(200, 1000+50), (0, 800), (-150, 500)]

def addPlot(ax, index1=0, index2=1):
  c = 0
  ax.scatter(trim_track[:,:,index1], trim_track[:,:,index2], s=15, edgecolor='black', color='pink', alpha=0.1, zorder=2, label="All Data")
  first = "FPGA returned"
  for t in tracks:
    t = np.array([h for h in t if h[0] != 0])
    ax.plot(t[:,index1], t[:,index2], marker='o', ms=np.sqrt(15), markeredgecolor='black', linestyle=':', color='red', alpha=1, zorder=5, label=first)
    first = None
    for h in t:
      ax.add_patch(plt.Circle((h[index1], h[index2]), np.sqrt(3000)/3, edgecolor='black', color='blue', alpha=0.2, zorder=1))
      # ax.add_patch(plt.Circle((h[index1], h[index2]), np.sqrt(3000), edgecolor='black', fill=False, zorder=9))

    # bnds = [bounds[index1][0], bounds[index1][1], bounds[index2][0], bounds[index2][1]]
    # for h in t:
    #   x, y = np.meshgrid(np.linspace(bnds[0], bnds[1], 500), np.linspace(bnds[2], bnds[3], 500))
    #   r = np.sqrt((x - h[index1]) ** 2 + (y - h[index2]) ** 2)
    #   # z = np.where(r < np.sqrt(3000), np.nan, np.clip(np.sqrt(6000) - r, 0, np.inf))
    #   z = np.clip(1/r, 0, 1/15)
    #   cmap = LinearSegmentedColormap.from_list('', ['#FFFFFF00', 'red'])
    #   # cmap = LinearSegmentedColormap.from_list('', ['red', '#FFFFFF00'])
    #   # cmap.set_bad('#ff334466')
    #   ax.imshow(z, cmap=cmap, extent=bnds, origin='lower', zorder=3)

    ax.text(t[-1, index1] + 10, t[-1, index2] + 10, "{}".format(c), zorder=10, color='blue', fontsize=8)
    c+=1

  first = "NNScore>0.5"
  c = 0
  for t in trim2_track:
    t = np.array([h for h in t if h[0] != 0])
    ax.plot(t[:,index1], t[:,index2], marker='o', ms=np.sqrt(15), markeredgecolor='black', linestyle=':', color='green', alpha=0.7, zorder=4, label=first)
    first = None
    ax.text(t[-1, index1] + 10, t[-1, index2] + 10, "{}".format(trim2_ids[c]), zorder=10, color='red', fontsize=8)
    c+=1
  # print(trim2_NN)
  ax.grid(True)
  ax.legend()
  ax.set_xlabel(labels[index1])
  ax.set_ylabel(labels[index2])
  ax.set_xlim(bounds[index1])
  ax.set_ylim(bounds[index2])
  ax.set_title("{} vs {}".format(labels[index2], labels[index1]))

def radial(x, y):
  return np.sqrt(x**2 + y**2)

def addRadial(ax):
  c = 0
  ax.scatter(trim_track[:,:,2], radial(trim_track[:,:,0], trim_track[:,:,1]), s=15, edgecolor='black', color='pink', alpha=0.1, zorder=2, label="All Data")
  first = "FPGA returned"
  for t in tracks:
    t = np.array([h for h in t if h[0] != 0])
    ax.plot(t[:,2], radial(t[:,0], t[:,1]), marker='o', ms=np.sqrt(15), markeredgecolor='black', linestyle=':', color='red', alpha=1, zorder=5, label=first)
    first = None
    # for h in t:
    #   ax.add_patch(plt.Circle((h[2], radial(h[0], h[1])), np.sqrt(3000), edgecolor='black', fill=False, zorder=9))
    ax.text(t[-1,2], radial(t[-1, 0] + 10, t[-1, 1] + 10), "{}".format(c), zorder=10, color='blue', fontsize=8)
    c+=1

  first = "NNScore>0.5"
  c=0
  for t in trim2_track:
    t = np.array([h for h in t if h[0] != 0])
    ax.plot(t[:,2], radial(t[:,0], t[:,1]), marker='o', ms=np.sqrt(15), markeredgecolor='black', linestyle=':', color='green', alpha=0.7, zorder=4, label=first)
    first = None
    ax.text(t[-1,2], radial(t[-1, 0] + 10, t[-1, 1] + 10), "{}".format(trim2_ids[c]), zorder=10, color='red', fontsize=8)
    c+=1

  # print(trim2_NN)
  ax.grid(True)
  ax.legend()
  ax.set_xlabel("z")
  ax.set_ylabel("r")
  # ax.set_xlim()
  ax.set_ylim(200, 1000+50)
  ax.set_title("Radial Vs Z")

# %%
fig, ((ax0, ax1), (ax2, ax3)) = plt.subplots(2,2, figsize=(15,15))

addPlot(ax0, 0,1)
addPlot(ax2, 0,2)
addPlot(ax1, 2,1)
addRadial(ax3)

fig.savefig("rejected_tracks.png", dpi=400)
# Out:
# /tmp/ipykernel_209084/3954667877.py:14: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.add_patch(plt.Circle((h[index1], h[index2]), np.sqrt(3000)/3, edgecolor='black', color='blue', alpha=0.2, zorder=1))

# %%
with open("data/recoTracks.txt") as file:
  rdata = file.read()

# with open("data/truthTracks.txt") as file:
#   truth = file.read()

rdata = rdata.split("Track: ")[1:]

fdata = []
for track in rdata:
  halved = track.split("---------- sp --------------\n")
  trackinfo = halved[0].split("\n")[1]
  truthinfo = halved[1].split("\n")[-2].split(" ")[-1][:-14]
  hitinfo = halved[1].split("\n")[:-2]
  fdata.append([trackinfo, truthinfo, hitinfo])


print(fdata[:10])

# rdata = [[d.split("\n")[1], d.split("\n")[-2], d.split("\n")[-7:-2]] for d in rdata]
# Out:
# [['RecoTrack index: 0 pt: 0.986301 eta: 0 phi: 0.33287 prob: 0.25 nHits: 8 truth: 0 NN Score: 0 computed prob: 0.222222', '18446744073709551615', ['Hit index: 0 0 x: 263.937 y: 117.795 z: 19.9355 rho: 289.03 r: 289.717 pixOrSCT: 0 volumeID: 1 layerID: 0 moduleID: 5402 side: 0 nTruthBarCode: 18446744073709551615\\', 'Hit index: 1 0 x: 349.363 y: 169.304 z: 182.233 rho: 388.225 r: 428.868 pixOrSCT: 1 volumeID: 1 layerID: 1 moduleID: 14395 side: 0 nTruthBarCode: 18446744073709551615\\', 'Hit index: 0 0 x: 488.266 y: 267.997 z: 164.256 rho: 556.979 r: 580.694 pixOrSCT: 1 volumeID: 1 layerID: 3 moduleID: 20890 side: -1 nTruthBarCode: 5210025\\', 'Hit index: 1 0 x: 637.573 y: 403.633 z: 146.583 rho: 754.598 r: 768.703 pixOrSCT: 1 volumeID: 1 layerID: 5 moduleID: 30297 side
 moduleID: 5404 side: 0 nTruthBarCode: 18446744073709551615\\', 'Hit index: 9 0 x: 347.076 y: 185.683 z: 121.807 rho: 393.624 r: 412.04 pixOrSCT: 1 volumeID: 1 layerID: 1 moduleID: 14393 side: -1 nTruthBarCode: 719\\', 'Hit index: 27 0 x: 483.184 y: 291.965 z: 135.08 rho: 564.544 r: 580.48 pixOrSCT: 1 volumeID: 1 layerID: 4 moduleID: 20893 side: 0 nTruthBarCode: 5460049\\', 'Hit index: 10 0 x: 626.025 y: 430.376 z: 117.288 rho: 759.692 r: 768.692 pixOrSCT: 1 volumeID: 1 layerID: 5 moduleID: 30297 side: -1 nTruthBarCode: 5500054\\', 'Hit index: 11 0 x: 782.681 y: 630.17 z: 175.874 rho: 1004.84 r: 1020.12 pixOrSCT: 1 volumeID: 1 layerID: 7 moduleID: 43296 side: -1 nTruthBarCode: 5500054\\']], ['RecoTrack index: 4 pt: 0.995392 eta: 0 phi: 0.371759 prob: 0.5 nHits: 8 truth: 0 NN Score: 2.5034e-06 computed prob: 0.444444', '18446744073709551615', ['Hit index: 3 ...

# %%
import pandas as pd
import collections

info = collections.defaultdict(list)
for trackid, track in enumerate(fdata[2000:]):
  truth = (0 if (track[1] == "18446744073709551615") else 1)
  # print(truth)
  tparts = track[0].split(" ")
  for hitid in range(5):
    # print("len:",len(track[2]))
    # print("hitid:",hitid)
    if hitid < len(track[2]):
      hit = track[2][hitid]
      hit = hit[:-1]
      parts = hit.split(" ")
    else:
      parts = np.zeros(13)
    # print(hit)
    info["trackid"].append(trackid)
    info["hitid"].append(hitid)
    info["pt"].append(float(tparts[4]))
    # info["prob"].append(float(tparts[10]))
    info["truth"].append(truth)
    info["nnscore"].append(float(tparts[17]))

    info["x"].append(float(parts[5]))
    info["y"].append(float(parts[7]))
    info["z"].append(float(parts[9]))
    # hitinfo["rho"] = parts[11]
    # hitinfo["r"] = parts[13]
    # hitlist.append(hitinfo)
    
  
data = pd.DataFrame(info)
data
# Out:
#          trackid  hitid       pt  truth   nnscore        x        y        z
# 0              0      0  1.72800      0  0.000000  265.303  111.205  202.380
# 1              0      1  1.72800      0  0.000000  375.823  168.243  134.059
# 2              0      2  1.72800      0  0.000000  513.452  246.197  137.653
# 3              0      3  1.72800      0  0.000000  672.157  351.390  111.746
# 4              0      4  1.72800      0  0.000000  859.989  495.166  215.538
# ...          ...    ...      ...    ...       ...      ...      ...      ...
# 1276740   255348      0  2.13861      0  0.001823  264.445  115.347  177.989
# 1276741   255348      1  2.13861      0  0.001823  373.870  156.652  240.560
# 1276742   255348      2  2.13861      0  0.001823  520.914  205.937  256.651
# 1276743   255348      3  2.13861      0  0.001823  710.090  258.728  356.687
# 1276744   255348      4  2.13861      0  0.001823  949.629  308.229  465.498
#
# [1276745 rows x 8 columns]

# %%
data[data["truth"] == 1]
# Out:
#          trackid  hitid       pt  truth   nnscore        x         y         z
# 490           98      0  1.75610      1  0.017358  273.323  110.6740  123.7280
# 491           98      1  1.75610      1  0.017358  373.644  158.7120  174.4290
# 492           98      2  1.75610      1  0.017358  515.308  236.1800  149.4200
# 493           98      3  1.75610      1  0.017358  677.040  335.3440  173.3610
# 494           98      4  1.75610      1  0.017358  879.713  486.3880  252.4010
# ...          ...    ...      ...    ...       ...      ...       ...       ...
# 1197470   239494      0  1.62406      1  0.057511  275.558   86.5105   42.5922
# 1197471   239494      1  1.62406      1  0.057511  378.853  111.4140   65.2193
# 1197472   239494      2  1.62406      1  0.057511  546.157  143.2310   92.3710
# 1197473   239494      3  1.62406      1  0.057511  752.795  165.5710   74.3273
# 1197474   239494      4  1.62406      1  0.057511  985.739  172.8110   92.9393
#
# [446730 rows x 8 columns]

# %%
data.dtypes
# Out:
# trackid      int64
# hitid        int64
# pt         float64
# truth        int64
# nnscore    float64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
THRESHOLD = 0.5
total_length = len(data)
total_truth= len(data[data["truth"] == 1])
total_threshold = len(data[data["nnscore"] > THRESHOLD])
total_true_thresholded = len(data[(data["nnscore"] > THRESHOLD) & (data["truth"] == 1)])

print("total length:           {}".format(total_length))
print("total truth:            {}".format(total_truth))
print("total threshold:        {}".format(total_threshold))
print("total true thresholded: {}".format(total_true_thresholded))
print()
print("percent truth:       {:.2f} %".format(100*total_truth/total_length))
print("percent threshold:   {:.2f} %".format(100*total_threshold/total_length))
print("percent true trehs:  {:.2f} %".format(100*total_true_thresholded/total_length))
# Out:
# total length:           1276745
# total truth:            446730
# total threshold:        247745
# total true thresholded: 169410
#
# percent truth:       34.99 %
# percent threshold:   19.40 %
# percent true trehs:  13.27 %

# %%
data.to_csv("data/formatted_data.csv", index=False, float_format='%.15f')

# %%
plt.hist(data["truth"], bins=2)
plt.show()

plt.hist(data["nnscore"], bins=10)
plt.show()

plt.hist(data["pt"], bins=10)
plt.show()

# %%
a = len(data.groupby(["trackid"]))
b = len(data[data["truth"] == 1].groupby(["trackid"]))
print(a)
print(b)
print(b/a*100)
# Out:
# 255349
# 89346
# 34.98975911399692

# %%
data[data["truth"] == 1]
# Out:
#          trackid  hitid       pt  truth   nnscore        x         y         z
# 490           98      0  1.75610      1  0.017358  273.323  110.6740  123.7280
# 491           98      1  1.75610      1  0.017358  373.644  158.7120  174.4290
# 492           98      2  1.75610      1  0.017358  515.308  236.1800  149.4200
# 493           98      3  1.75610      1  0.017358  677.040  335.3440  173.3610
# 494           98      4  1.75610      1  0.017358  879.713  486.3880  252.4010
# ...          ...    ...      ...    ...       ...      ...       ...       ...
# 1197470   239494      0  1.62406      1  0.057511  275.558   86.5105   42.5922
# 1197471   239494      1  1.62406      1  0.057511  378.853  111.4140   65.2193
# 1197472   239494      2  1.62406      1  0.057511  546.157  143.2310   92.3710
# 1197473   239494      3  1.62406      1  0.057511  752.795  165.5710   74.3273
# 1197474   239494      4  1.62406      1  0.057511  985.739  172.8110   92.9393
#
# [446730 rows x 8 columns]

# %%
data[data["truth"] == 1]["trackid"].unique()
# Out:
# array([    98,    102,    106, ..., 239478, 239486, 239494])
